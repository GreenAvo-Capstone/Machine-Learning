# %%
import numpy as np
import pandas as pd
import os

# %%
from PIL import Image
pth = 'dataset/'

# Underripe Avocado
Underripe_image_path = pth+'Underripe/T10_d01_002_a_1.jpg'
Underripe_image = Image.open(Underripe_image_path)
print("Image Dimensions: ", Underripe_image.size)
Underripe_image
# Out:
# Image Dimensions:  (800, 800)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %%
from PIL import Image
pth = 'dataset/'

# Breaking Avocado
Breaking_image_path = pth+'Breaking/T10_d02_065_a_2.jpg'
Breaking_image = Image.open(Breaking_image_path)
print("Image Dimensions: ", Breaking_image.size)
Breaking_image
# Out:
# Image Dimensions:  (800, 800)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800>

# %%
from PIL import Image
pth = 'dataset/'

# Ripe First Stage Avocado
RipeFS_image_path = pth+'Breaking/T10_d02_065_a_2.jpg'
Breaking_image = Image.open(Breaking_image_path)
print("Image Dimensions: ", Breaking_image.size)
Breaking_image
